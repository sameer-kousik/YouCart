# %%
client_id = 'youcart-2432612430342445485a5a477273704a627733736250477a4632716b755065315637767a694b6766726662436642514c6b466e716e366b61376c34435477106669341475649'

# %%
client_secret = 'GNsqKkrpTqn9a8y1gfT1dW4uecYjPDnxOWn4mWOP'

# %%
k_path = 'https://api.kroger.com/v1/'
